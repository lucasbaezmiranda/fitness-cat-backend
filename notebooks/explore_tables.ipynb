# %% [markdown]
# ## Registered Users

# %%
import boto3
import pandas as pd
from boto3.dynamodb.conditions import Attr

# 1. Configuración de la sesión
# Si usas perfiles locales, añade profile_name='tu-perfil'
dynamodb = boto3.resource('dynamodb', region_name='us-east-1') 
table = dynamodb.Table('user_profiles')

# 2. Escaneo de la tabla
# Nota: .scan() es costoso en tablas gigantes, pero ideal para inspección rápida
response = table.scan()
items = response.get('Items', [])

# 3. Manejo de paginación (por si tienes más de 1MB de datos)
while 'LastEvaluatedKey' in response:
    response = table.scan(ExclusiveStartKey=response['LastEvaluatedKey'])
    items.extend(response.get('Items', []))

# 4. Visualización en Pandas
df = pd.DataFrame(items)

# Reordenar columnas para que el ID aparezca primero (opcional)
if not df.empty:
    cols = df.columns.tolist()
    # Cambia 'user_id' por tu Partition Key real si es distinta
    if 'user_id' in cols:
        cols.insert(0, cols.pop(cols.index('user_id')))
        df = df[cols]

print(f"Total de registros encontrados: {len(df)}")
df # Muestra las primeras 5 filas
# Out:
# Total de registros encontrados: 12
#                            user_id         city           nickname  \
# 0   8397dcccd645feee_1772230450825      Rosario            lucasbm
# 1   2f31ffd33f9d7ea6_1772301167972          NaN              bunny
# 2   8397dcccd645feee_1772222578572      Rosario        lucasbaezm4
# 3   568e488267ffc3ad_1772208257363      Quilmes                 Lu
# 4   8397dcccd645feee_1772223253226      Rosario         lucasbaez5
# 5   8397dcccd645feee_1772207177968  Cap Federal        lucasbaezm1
# 6   8397dcccd645feee_1772236859296      Caseros        lucasbaezm7
# 7   8397dcccd645feee_1772225125459      Rosario         Lucasbaez6
# 8   3b0ccc966d0a7289_1772208499305       Bernal               Mart
# 9   568e488267ffc3ad_1772216317571      Quilmes                 Lu
# 10  8397dcccd645feee_1772209358752      Rosario  lucasbaezmiranda2
# 11  8397dcccd645feee_1772317242964          NaN                NaN
#
#                                             fcm_token urban_context  \
# 0   cVaZ8J4XSfG64tOgJN8zVo:APA91bHPh-5qWAYUxeaq4TT...       Suburbs
# 1                                                 NaN          City
# 2                                                 NaN          City
# 3                                                 NaN       Suburbs
# 4                                                 NaN       Suburbs
# 5                                                 NaN          City
# 6   eWGfnPX9SPqdNDRhi1-KFE:APA91bFkKyhZENoSp37QPE5...   Countryside
# 7                                                 NaN          City
# 8                                                 NaN       Suburbs
# 9                                                 NaN       Suburbs
# 10                                                NaN          City
# 11  e3o_C4eJTSKE_4cqPg61oQ:APA91bF2cnQnW1Dj4Ku2Qr0...           NaN
#
#       country  gender  age
# 0   Argentina    Male   30
# 1   Argentina    Male  <14
# 2   Argentina    Male   24
# 3   Argentina  Female   27
# 4   Argentina    Male   25
# 5   Argentina    Male  <14
# 6   Argentina    Male   21
# 7   Argentina    Male   28
# 8   Argentina    Male   26
# 9   Argentina  Female   27
# 10  Argentina    Male   30
# 11        NaN     NaN  NaN

# %% [markdown]
# ## User Activity

# %%
import boto3
import pandas as pd
from boto3.dynamodb.conditions import Attr
from datetime import datetime

# 1. Configuración de la sesión
# Si usas perfiles locales, añade profile_name='tu-perfil'
dynamodb = boto3.resource('dynamodb', region_name='us-east-1') 
table = dynamodb.Table('user_activity')

# 2. Escaneo de la tabla
# Nota: .scan() es costoso en tablas gigantes, pero ideal para inspección rápida
response = table.scan()
items = response.get('Items', [])

# 3. Manejo de paginación (por si tienes más de 1MB de datos)
while 'LastEvaluatedKey' in response:
    response = table.scan(ExclusiveStartKey=response['LastEvaluatedKey'])
    items.extend(response.get('Items', []))

# 4. Visualización en Pandas
df = pd.DataFrame(items)

# Reordenar columnas para que el ID aparezca primero (opcional)
if not df.empty:
    cols = df.columns.tolist()
    # Cambia 'user_id' por tu Partition Key real si es distinta
    if 'user_id' in cols:
        cols.insert(0, cols.pop(cols.index('user_id')))
        df = df[cols]

print(f"Total de registros encontrados: {len(df)}")
df["time"] = df["timestamp"].apply(lambda x: datetime.fromtimestamp(int(x)).strftime('%d/%m/%Y %H:%M:%S')) # Muestra las primeras 5 filas
df.tail(15)
# Out:
# Total de registros encontrados: 78
#                            user_id avg_speed_kmh activity latitude longitude  \
# 63  8397dcccd645feee_1772236859296           NaN      NaN      NaN       NaN
# 64  8397dcccd645feee_1772317242964           NaN      NaN      NaN       NaN
# 65  8397dcccd645feee_1772317242964           NaN      NaN      NaN       NaN
# 66  8397dcccd645feee_1772317242964           NaN      NaN      NaN       NaN
# 67  8397dcccd645feee_1772317242964           NaN      NaN      NaN       NaN
# 68  8397dcccd645feee_1772317242964           NaN      NaN      NaN       NaN
# 69  8397dcccd645feee_1772317242964           NaN      NaN      NaN       NaN
# 70  8397dcccd645feee_1772317242964           NaN      NaN      NaN       NaN
# 71  8397dcccd645feee_1772317242964           NaN      NaN      NaN       NaN
# 72  8397dcccd645feee_1772317242964           NaN      NaN      NaN       NaN
# 73  8397dcccd645feee_1772317242964           NaN      NaN      NaN       NaN
# 74  8397dcccd645feee_1772317242964           NaN      NaN      NaN       NaN
# 75  8397dcccd645feee_1772317242964           NaN      NaN      NaN       NaN
# 76  8397dcccd645feee_1772317242964           NaN      NaN      NaN       NaN
# 77  8397dcccd645feee_1772317242964           NaN      NaN      NaN       NaN
#
#      timestamp still_min on_foot_min on_bicycle_min walking_min unknown_min  \
# 63  1772331960         0           0              0           0           0
# 64  1772318144         0           0              0           0           0
# 65  1772319045         0           0              0           0          15
# 66  1772319945         0           0              0           0          15
# 67  1772320845         0           0              0           0          15
# 68  1772321745         0           0              0           0          15
# 69  1772322878         0           0              0           0          18
# 70  1772323798         0           0              0           0          15
# 71  1772324992         0           0              0           0          19
# 72  1772325892         0           0              0           0          15
# 73  1772326799         0           0              0           0          15
# 74  1772327703         0           0              0           0          15
# 75  1772328603         0           0              0           0          15
# 76  1772329509         0           0              0           0          15
# 77  1772330423         0           0              0           0          15
#
#    in_vehicle_min running_min                 time
# 63              0           0  28/02/2026 23:26:00
# 64              0           0  28/02/2026 19:35:44
# 65              0           0  28/02/2026 19:50:45
# 66              0           0  28/02/2026 20:05:45
# 67              0           0  28/02/2026 20:20:45
# 68              0           0  28/02/2026 20:35:45
# 69              0           0  28/02/2026 20:54:38
# 70              0           0  28/02/2026 21:09:58
# 71              0           0  28/02/2026 21:29:52
# 72              0           0  28/02/2026 21:44:52
# 73              0           0  28/02/2026 21:59:59
# 74              0           0  28/02/2026 22:15:03
# 75              0           0  28/02/2026 22:30:03
# 76              0           0  28/02/2026 22:45:09
# 77              0           0  28/02/2026 23:00:23

# %%
import boto3
import pandas as pd
from boto3.dynamodb.conditions import Attr

# 1. Configuración de la sesión
# Si usas perfiles locales, añade profile_name='tu-perfil'
dynamodb = boto3.resource('dynamodb', region_name='us-east-1') 
table = dynamodb.Table('user_steps')

# 2. Escaneo de la tabla
# Nota: .scan() es costoso en tablas gigantes, pero ideal para inspección rápida
response = table.scan()
items = response.get('Items', [])

# 3. Manejo de paginación (por si tienes más de 1MB de datos)
while 'LastEvaluatedKey' in response:
    response = table.scan(ExclusiveStartKey=response['LastEvaluatedKey'])
    items.extend(response.get('Items', []))

# 4. Visualización en Pandas
df = pd.DataFrame(items)

# Reordenar columnas para que el ID aparezca primero (opcional)
if not df.empty:
    cols = df.columns.tolist()
    # Cambia 'user_id' por tu Partition Key real si es distinta
    if 'user_id' in cols:
        cols.insert(0, cols.pop(cols.index('user_id')))
        df = df[cols]

print(f"Total de registros encontrados: {len(df)}")
df["time"] = df["timestamp"].apply(lambda x: datetime.fromtimestamp(int(x)).strftime('%d/%m/%Y %H:%M:%S')) # Muestra las primeras 5 filas
df.sort_values(by="timestamp", ascending=False, inplace=True)
df.to_excel("data_user_steps.xlsx", index=False)
# Out:
# Total de registros encontrados: 2332
#                              user_id  steps   timestamp     latitude  \
# 1539  8397dcccd645feee_1772332603557  29386  1772334009          NaN
# 1538  8397dcccd645feee_1772332603557  29386  1772333992          NaN
# 1537  8397dcccd645feee_1772332603557  29386  1772333770          NaN
# 1536  8397dcccd645feee_1772332603557  29386  1772333247  -34.6543647
# 1535  8397dcccd645feee_1772332603557  29386  1772332656          NaN
# 1534  8397dcccd645feee_1772332603557  29386  1772332636          NaN
# 2280  8397dcccd645feee_1772332441660  29386  1772332500          NaN
# 2279  8397dcccd645feee_1772332441660  29386  1772332490          NaN
# 2278  8397dcccd645feee_1772332441660  29386  1772332481          NaN
# 1533  8397dcccd645feee_1772236859296  67619  1772331969          NaN
#
#         longitude                 time
# 1539          NaN  01/03/2026 00:00:09
# 1538          NaN  28/02/2026 23:59:52
# 1537          NaN  28/02/2026 23:56:10
# 1536  -58.5326029  28/02/2026 23:47:27
# 1535          NaN  28/02/2026 23:37:36
# 1534          NaN  28/02/2026 23:37:16
# 2280          NaN  28/02/2026 23:35:00
# 2279          NaN  28/02/2026 23:34:50
# 2278          NaN  28/02/2026 23:34:41
# 1533          NaN  28/02/2026 23:26:09
